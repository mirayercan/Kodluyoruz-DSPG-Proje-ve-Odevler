# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\Miray\\Desktop\\miray_ercan_hw4\\finance.csv",encoding='latin1')

# %%
#https://www.kaggle.com/jilkothari/finance-accounting-courses-udemy-13k-course

# %%
df
# Out:
#             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 13603  3005408  ×××©××× ××¡××¡××× ××××¤×¦×××ª ×...
# 13604  3467284                            Programa de Integridade
# 13605  3368222  Goodwill and Method of Calculating Goodwill (A...
# 13606  3211345                                Poderoso Investidor
# 13607  2935720        Acabou a PrevidÃªncia e agora? -  Volume 03
#
#                                                      url  is_paid  \
# 0                     /course/the-complete-sql-bootcamp/     True
# ...

# %%
df.head()
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
#
#                                                  url  is_paid  \
# 0                 /course/the-complete-sql-bootcamp/     True
# 1                                 /course/tableau10/     True
# 2                        /course/pmp-pmbok6-35-pdus/     True
# 3     /course/the-complete-financial-analyst-course/     True
# 4  /course/an-entire-mba-in-1-courseaward-winning...     True
#
#    num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           295509     4.66019            4.67874  4.67874        78006
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'url', 'is_paid', 'num_subscribers', 'avg_rating',
#        'avg_rating_recent', 'rating', 'num_reviews', 'is_wishlisted',
#        'num_published_lectures', 'num_published_practice_tests', 'created',
#        'published_time', 'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string'],
#       dtype='object')

# %%
df.drop(['price_detail__price_string','price_detail__currency','discount_price__price_string','url'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (13608, 16)

# %%
df.dropna(how="any",inplace=True)

# %%
df
# Out:
#             id                                              title  is_paid  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...     True
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...     True
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6     True
# 3       648826         The Complete Financial Analyst Course 2020     True
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...     True
# ...        ...                                                ...      ...
# 13388  2748296               CÃ³mo hacer staking de criptomonedas     True
# 13389  2765400           TRADING Semplificato: I 5 Fattori Chiave     True
# 13390  2853024                        Geld mit Youtube verdienen!     True
# 13391  2832286                                Trading: Indices NQ     True
# 13392  2964842                        A MatemÃ¡tica para investir     True
#
# ...

# %%
wishgroup_mean=df.groupby(['is_wishlisted']).mean()

# %%
wishgroup_mean
# Out:
#                          id  is_paid  num_subscribers  avg_rating  \
# is_wishlisted
# False          1.663674e+06     True      2858.483818    3.932067
#
#                avg_rating_recent    rating  num_reviews  \
# is_wishlisted
# False                   3.919303  3.919303    247.38222
#
#                num_published_lectures  num_published_practice_tests  \
# is_wishlisted
# False                       32.870463                      0.115035
#
#                discount_price__amount  price_detail__amount
# is_wishlisted
# False                      493.943794            4616.46866

# %%
df2=pd.DataFrame(df)
df.shape
# Out:
# (12205, 16)

# %%
df["avg_rating"].plot(kind="hist",color="#ff9999")

# %%
df.plot(kind='scatter',x='avg_rating',y='num_reviews',color='red')
plt.show()

# %%
#df.plot(kind="",x="num_published_lectures",y="num_subscribers",color="blue")
ax = df.plot.kde(bw_method=3,x="num_published_lectures",y="num_subscribers",color="#669900")

# %%
df.groupby('num_published_lectures')['id'].nunique().plot(kind='line')
plt.show()

# %%
df.shape
# Out:
# (12205, 16)

# %%
df["published_time"] = pd.to_datetime(df["published_time"])
df["publication_year"] = df["published_time"].dt.year
year_df = df[("publication_year")]

df["created"]=pd.to_datetime(df["created"])
df["created_year"]=df["created"].dt.year
year_df2=df[("created_year")]

year_diff=(year_df)-(year_df2)

df.insert(16,"year_diff",year_diff,True)

# %%
df
# Out:
#             id                                              title  is_paid  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...     True
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...     True
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6     True
# 3       648826         The Complete Financial Analyst Course 2020     True
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...     True
# ...        ...                                                ...      ...
# 13388  2748296               CÃ³mo hacer staking de criptomonedas     True
# 13389  2765400           TRADING Semplificato: I 5 Fattori Chiave     True
# 13390  2853024                        Geld mit Youtube verdienen!     True
# 13391  2832286                                Trading: Indices NQ     True
# 13392  2964842                        A MatemÃ¡tica para investir     True
#
# ...

# %%
years = [year for year, df in df.groupby(['publication_year'])]
plt.bar(years,df.groupby(['publication_year']).sum()['price_detail__amount'])
# Out:
# <BarContainer object of 11 artists>

# %%
years2=[year for year,df in df.groupby(['created_year'])]

plt.bar(years2,df.groupby(['created_year']).mean()['price_detail__amount'])
# Out:
# <BarContainer object of 11 artists>

# %%
df.plot(kind='scatter',x='year_diff',y='price_detail__amount',color='purple')
plt.show()

# %%
df.shape
# Out:
# (12205, 19)

# %%
df['check'] = df['is_paid'].apply(lambda x: '0' if x =="True" else '1')

# %%
df.plot(kind='box',x='check',y='num_reviews',color='black')
plt.show()

# %%
df
# Out:
#             id                                              title  is_paid  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...     True
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...     True
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6     True
# 3       648826         The Complete Financial Analyst Course 2020     True
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...     True
# ...        ...                                                ...      ...
# 13388  2748296               CÃ³mo hacer staking de criptomonedas     True
# 13389  2765400           TRADING Semplificato: I 5 Fattori Chiave     True
# 13390  2853024                        Geld mit Youtube verdienen!     True
# 13391  2832286                                Trading: Indices NQ     True
# 13392  2964842                        A MatemÃ¡tica para investir     True
#
# ...

# %%
filt2 = df["publication_year"] == 2016
df.loc[filt2]
df3=df.loc[filt2]["num_published_lectures"].value_counts()
df3.plot(kind='hist',x='filt2',y="num_published_lectures",color='#32a4bb')
plt.show()

# %%
group_2=df.groupby(['publication_year'])
plt.show()

# %%
filt=df["created_year"] == 2016
df.loc[filt]
df4=df.loc[filt]["price_detail__amount"]
df4.plot(kind='hist',x='filt',y='num_reviews',color='#cc6699',edgecolor="black")
plt.show()

# %%
df
# Out:
#             id                                              title  is_paid  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...     True
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...     True
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6     True
# 3       648826         The Complete Financial Analyst Course 2020     True
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...     True
# ...        ...                                                ...      ...
# 13388  2748296               CÃ³mo hacer staking de criptomonedas     True
# 13389  2765400           TRADING Semplificato: I 5 Fattori Chiave     True
# 13390  2853024                        Geld mit Youtube verdienen!     True
# 13391  2832286                                Trading: Indices NQ     True
# 13392  2964842                        A MatemÃ¡tica para investir     True
#
# ...

# %%
df2=df.iloc[0:100]
df2.set_index('price_detail__amount')
df2.groupby('created_year')['price_detail__amount'].plot(kind="density",legend=True)
# Out:
# created_year
# 2013    AxesSubplot(0.125,0.125;0.775x0.755)
# 2014    AxesSubplot(0.125,0.125;0.775x0.755)
# 2015    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017    AxesSubplot(0.125,0.125;0.775x0.755)
# 2018    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: price_detail__amount, dtype: object

# %%
filt=df["created_year"] == 2011
df2=df.loc[filt]
df2.plot(kind='hist',x='num_published_lectures',y='num_reviews',bins=5,color='purple')
plt.show()

# %%
df5=pd.DataFrame(df["created_year"].iloc[0:10])

# %%
df5
# Out:
#    created_year
# 0          2016
# 1          2016
# 2          2017
# 3          2015
# 4          2015
# 5          2017
# 6          2016
# 7          2014
# 8          2015
# 9          2018

# %%
df5['review']=df["num_reviews"].iloc[0:10]
df5['Year']=df["publication_year"].iloc[0:10]

# %%
df5
# Out:
#    created_year  review  Year
# 0          2016   78006  2016
# 1          2016   54581  2016
# 2          2017   52653  2017
# 3          2015   46447  2016
# 4          2015   41630  2016
# 5          2017   38093  2017
# 6          2016   30470  2016
# 7          2014   28665  2014
# 8          2015   27408  2016
# 9          2018   23906  2018

# %%
df5.plot(kind='scatter',x='review',y="Year")

plt.show()

# %%
df6 = pd.DataFrame(df5) 
df6.style.background_gradient(cmap ='viridis').set_properties(**{'font-size': '10px'})
# Out:
# <style  type="text/css" >
#     #T_df6cad63_4969_11eb_8e32_e86a64f61f52row0_col0 {
#             background-color:  #21918c;
#             color:  #000000;
#             font-size:  10px;
#         }    #T_df6cad63_4969_11eb_8e32_e86a64f61f52row0_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#             font-size:  10px;
#         }    #T_df6cad63_4969_11eb_8e32_e86a64f61f52row0_col2 {
#             background-color:  #21918c;
#             color:  #000000;
#             font-size:  10px;
#         }    #T_df6cad63_4969_11eb_8e32_e86a64f61f52row1_col0 {
#             background-color:  #21918c;
#             color:  #000000;
#             font-size:  10px;
#         }    #T_df6cad63_4969_11eb_8e32_e86a64f61f52row1_col1 {
#             background-color:  #1fa188;
#             color:  #000000;
#             font-size:  10px;
#         }    #T_df6cad63_4969_11eb_8e32_e86a64f61f52row1_col2 {
#             background-color:  #21918c;
# ...
